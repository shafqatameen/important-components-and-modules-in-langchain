# %%
from langchain_community.document_loaders import PyPDFLoader
loader = PyPDFLoader("pdf_file.pdf")
doc=loader.load()
doc
# Out:
# [Document(metadata={'producer': 'Nitro Pro 13 (13.42.1.855)', 'creator': 'Nitro Pro 13 (13.42.1.855)', 'creationdate': '2023-09-22T23:58:25+05:30', 'moddate': '2023-09-22T23:58:25+05:30', 'author': 'Sarim Moin', 'title': 'Basic Details of the Team and Problem Statement', 'source': 'pdf_file.pdf', 'total_pages': 5, 'page': 0, 'page_label': '1'}, page_content='Basic Details of the Team and \nProblem Statement \nMinistry/Organization Name/Student Innovation: \nPS Code:\n626126 \nProblem Statement Title: Chicken disease detection \nTeam Name: Core\nTeam Leader Name: Shafqat Ameen Mir \nInstitute Code (AISHE): NA \nInstitute Name:\nKalasalingam University \nTheme Name:'),
# ...

# %%
doc[0]
# Out:
# Document(metadata={'producer': 'Nitro Pro 13 (13.42.1.855)', 'creator': 'Nitro Pro 13 (13.42.1.855)', 'creationdate': '2023-09-22T23:58:25+05:30', 'moddate': '2023-09-22T23:58:25+05:30', 'author': 'Sarim Moin', 'title': 'Basic Details of the Team and Problem Statement', 'source': 'pdf_file.pdf', 'total_pages': 5, 'page': 0, 'page_label': '1'}, page_content='Basic Details of the Team and \nProblem Statement \nMinistry/Organization Name/Student Innovation: \nPS Code:\n626126 \nProblem Statement Title: Chicken disease detection \nTeam Name: Core\nTeam Leader Name: Shafqat Ameen Mir \nInstitute Code (AISHE): NA \nInstitute Name:\nKalasalingam University \nTheme Name:')

# %%
doc[4]
# Out:
# Document(metadata={'producer': 'Nitro Pro 13 (13.42.1.855)', 'creator': 'Nitro Pro 13 (13.42.1.855)', 'creationdate': '2023-09-22T23:58:25+05:30', 'moddate': '2023-09-22T23:58:25+05:30', 'author': 'Sarim Moin', 'title': 'Basic Details of the Team and Problem Statement', 'source': 'pdf_file.pdf', 'total_pages': 5, 'page': 4, 'page_label': '5'}, page_content='ALGORITHIMS \n01.Random Forest Algorithm \n02.Regression Algorithm \n03.Time series Algorithm \n04.Anomoli Detection Algorithm \n05.Encryption Algorithm \n06.Hashing Algorithm \n07.Precision Agriculture Algorithm \n5')

# %%
print(len(doc))
# Out:
# 5

# %%
print(type(doc))
# Out:
# <class 'list'>

# %%
print(type(doc[0]))
# Out:
# <class 'langchain_core.documents.base.Document'>

# %% [markdown]
# --------------------------------------NOW i have loaded the document now i will use #textSplitter------------------------------------------------

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter= RecursiveCharacterTextSplitter(chunk_size=200,chunk_overlap=35)

text=text_splitter.split_documents(doc)

text
# Out:
# [Document(metadata={'producer': 'Nitro Pro 13 (13.42.1.855)', 'creator': 'Nitro Pro 13 (13.42.1.855)', 'creationdate': '2023-09-22T23:58:25+05:30', 'moddate': '2023-09-22T23:58:25+05:30', 'author': 'Sarim Moin', 'title': 'Basic Details of the Team and Problem Statement', 'source': 'pdf_file.pdf', 'total_pages': 5, 'page': 0, 'page_label': '1'}, page_content='Basic Details of the Team and \nProblem Statement \nMinistry/Organization Name/Student Innovation: \nPS Code:\n626126 \nProblem Statement Title: Chicken disease detection \nTeam Name: Core'),
# ...

# %%
print(text[0])
print(text[1])
# Out:
# page_content='Basic Details of the Team and
# Problem Statement
# Ministry/Organization Name/Student Innovation:
# PS Code:
# 626126
# Problem Statement Title: Chicken disease detection
# Team Name: Core' metadata={'producer': 'Nitro Pro 13 (13.42.1.855)', 'creator': 'Nitro Pro 13 (13.42.1.855)', 'creationdate': '2023-09-22T23:58:25+05:30', 'moddate': '2023-09-22T23:58:25+05:30', 'author': 'Sarim Moin', 'title': 'Basic Details of the Team and Problem Statement', 'source': 'pdf_file.pdf', 'total_pages': 5, 'page': 0, 'page_label': '1'}
# page_content='Team Name: Core
# Team Leader Name: Shafqat Ameen Mir
# Institute Code (AISHE): NA
# Institute Name:
# Kalasalingam University
# ...

# %% [markdown]
# ---------------------loading the .text file not pdf---------------------

# %%
from langchain_community.document_loaders import TextLoader
loader=TextLoader("speech.txt")
doc=loader.load()
doc
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content='hi my name is shafqat and i am from india\ni am a python developer\ni am a data scientist\ni am a machine learning expert\ni am a deep learning expert\ni am a natural language processing expert\ni am a computer vision expert\ni am a computer graphics expert\ni am a computer audio expert\ni am a computer vision expert')]

# %%
with open("speech.txt", "r", encoding="utf-8") as file:
    speech = file.read()

speech
# Out:
# 'hi my name is shafqat and i am from india\ni am a python developer\ni am a data scientist\ni am a machine learning expert\ni am a deep learning expert\ni am a natural language processing expert\ni am a computer vision expert\ni am a computer graphics expert\ni am a computer audio expert\ni am a computer vision expert'

# %%
text_splitter= RecursiveCharacterTextSplitter(chunk_size=100,chunk_overlap=20)

text=text_splitter.create_documents([speech])
text[0]
# Out:
# Document(metadata={}, page_content='hi my name is shafqat and i am from india\ni am a python developer\ni am a data scientist')

# %%
print(text[0])
print(text[1])
# Out:
# page_content='hi my name is shafqat and i am from india
# i am a python developer
# i am a data scientist'
# page_content='i am a machine learning expert
# i am a deep learning expert'

# %%
print(type(text))
# Out:
# <class 'list'>

# %%
print(type(text[0]))
# Out:
# <class 'langchain_core.documents.base.Document'>

# %%
from langchain_text_splitters import CharacterTextSplitter
text_splitter= CharacterTextSplitter(separator="\n", chunk_size=41, chunk_overlap=20)
text_splitter.create_documents([speech])
# Out:
# [Document(metadata={}, page_content='hi my name is shafqat and i am from india'),
#  Document(metadata={}, page_content='i am a python developer'),
#  Document(metadata={}, page_content='i am a data scientist'),
#  Document(metadata={}, page_content='i am a machine learning expert'),
#  Document(metadata={}, page_content='i am a deep learning expert'),
#  Document(metadata={}, page_content='i am a natural language processing expert'),
#  Document(metadata={}, page_content='i am a computer vision expert'),
#  Document(metadata={}, page_content='i am a computer graphics expert'),
#  Document(metadata={}, page_content='i am a computer audio expert'),
#  Document(metadata={}, page_content='i am a computer vision expert')]

# %% [markdown]
# ---------------------------------- -> text splitter html <- -------------------------------------

# %%
from langchain_text_splitters import HTMLHeaderTextSplitter
html_string = """
<!DOCTYPE html>
  <html lang='en'>
  <head>
    <meta charset='UTF-8'>
    <meta name='viewport' content='width=device-width, initial-scale=1.0'>
    <title>Fancy Example HTML Page</title>
  </head>
  <body>
    <h1>Main Title</h1>
    <p>This is an introductory paragraph with some basic content.</p>

    <h2>Section 1: Introduction</h2>
    <p>This section introduces the topic. Below is a list:</p>
    <ul>
      <li>First item</li>
      <li>Second item</li>
      <li>Third item with <strong>bold text</strong> and <a href='#'>a link</a></li>
    </ul>

    <h3>Subsection 1.1: Details</h3>
    <p>This subsection provides additional details. Here's a table:</p>
    <table border='1'>
      <thead>
        <tr>
          <th>Header 1</th>
          <th>Header 2</th>
          <th>Header 3</th>
        </tr>
      </thead>
      <tbody>
        <tr>
          <td>Row 1, Cell 1</td>
          <td>Row 1, Cell 2</td>
          <td>Row 1, Cell 3</td>
        </tr>
        <tr>
          <td>Row 2, Cell 1</td>
          <td>Row 2, Cell 2</td>
          <td>Row 2, Cell 3</td>
        </tr>
      </tbody>
    </table>

    <h2>Section 2: Media Content</h2>
    <p>This section contains an image and a video:</p>
      <img src='example_image_link.mp4' alt='Example Image'>
      <video controls width='250' src='example_video_link.mp4' type='video/mp4'>
      Your browser does not support the video tag.
    </video>

    <h2>Section 3: Code Example</h2>
    <p>This section contains a code block:</p>
    <pre><code data-lang="html">
    &lt;div&gt;
      &lt;p&gt;This is a paragraph inside a div.&lt;/p&gt;
    &lt;/div&gt;
    </code></pre>

    <h2>Conclusion</h2>
    <p>This is the conclusion of the document.</p>
  </body>
  </html>
"""

headers_to_split_on = [
    ("h1","header1"),
    ("h2","header2"), 
    ("h3","header3")
    ]

# %%
HTML_splitter = HTMLHeaderTextSplitter(headers_to_split_on=headers_to_split_on)
documents = HTML_splitter.split_text(html_string)

# %%
documents
# Out:
# [Document(metadata={'header1': 'Main Title'}, page_content='Main Title'),
#  Document(metadata={'header1': 'Main Title'}, page_content='This is an introductory paragraph with some basic content.'),
#  Document(metadata={'header1': 'Main Title', 'header2': 'Section 1: Introduction'}, page_content='Section 1: Introduction'),
#  Document(metadata={'header1': 'Main Title', 'header2': 'Section 1: Introduction'}, page_content='This section introduces the topic. Below is a list:  \nFirst item  \nSecond item  \nThird item with and  \nbold text  \na link'),
#  Document(metadata={'header1': 'Main Title', 'header2': 'Section 1: Introduction', 'header3': 'Subsection 1.1: Details'}, page_content='Subsection 1.1: Details'),
# ...

# %%
url="https://plato.stanford.edu/entries/goedel/"
heads_on_split=[
    ("h1" , "header1"),
    ("h2" , "header2"),
    ("h3" , "header3"),
    ("h4" , "header4"),
    ("h5" , "header5"),
    ("h6" , "header6")
]
html_splitter= HTMLHeaderTextSplitter(headers_to_split_on=heads_on_split)
documents=html_splitter.split_text_from_url(url)

# %%
documents
# Out:
# [Document(metadata={}, page_content='End container NOTE: Script required for drop-down button to work (mirrors).  \nEnd header wrapper End content End footer  \nEnd header  \nEnd navigation End search  \nStanford Encyclopedia of Philosophy  \nMenu  \nBrowse  \nTable of Contents  \nWhat\'s New  \nRandom Entry  \nChronological  \nArchives  \nAbout  \nEditorial Information  \nAbout the SEP  \nEditorial Board  \nHow to Cite the SEP  \nSpecial Characters  \nAdvanced Tools  \nContact  \nSupport SEP  \nSupport the SEP  \nPDFs for SEP Friends  \nMake a Donation  \nSEPIA for Libraries  \nBegin article sidebar End article sidebar NOTE: Article content must have two wrapper divs: id="article" and id="article-content" End article NOTE: article banner is outside of the id="article" div. End article-banner  \nEntry Navigation  \nEntry Contents  \nBibliography  \nAcademic Tools  \nFriends PDF Preview  \nAuthor and Citation Info  \nBack to Top  \nEnd article-content  \nBEGIN ARTICLE HTML #aueditable
# ...

# %% [markdown]
# ----------------------------------------> json text splitting <------------------------------------------

# %%
import requests
import json

# %%
json_file= requests.get("https://api.smith.langchain.com/openapi.json").json()

# %%
json_file
# Out:
# {'openapi': '3.1.0',
#  'info': {'title': 'LangSmith',
#   'description': 'The LangSmith API is used to programmatically create and manage LangSmith resources.\n\n## Host\nhttps://api.smith.langchain.com\n\n## Authentication\nTo authenticate with the LangSmith API, set the `X-Api-Key` header\nto a valid [LangSmith API key](https://docs.langchain.com/langsmith/create-account-api-key#create-an-api-key).\n\n',
#   'version': '0.1.0'},
#  'paths': {'/api/v1/audit-logs': {'get': {'tags': ['audit-logs'],
#     'summary': 'Get Audit Logs',
#     'description': "Retrieve audit log records for the authenticated user's organization in OCSF format.\n\nRequires both start_time and end_time parameters to filter logs within a date range.\nSupports cursor-based pagination.\n\nReturns results in OCSF API Activity (Class UID: 6003) format,\nwhich is compatible with security monitoring and SIEM tools.\nReference: https://schema.ocsf.io/1.7.0/classes/api_activity",
# ...

# %%
from langchain_text_splitters import RecursiveJsonSplitter

# %%
json_splitter=RecursiveJsonSplitter(max_chunk_size=300)
json_chunks=json_splitter.split_json(json_file)

# %%
json_chunks
# Out:
# [{'openapi': '3.1.0',
#   'info': {'title': 'LangSmith',
#    'description': 'The LangSmith API is used to programmatically create and manage LangSmith resources.\n\n## Host\nhttps://api.smith.langchain.com\n\n## Authentication\nTo authenticate with the LangSmith API, set the `X-Api-Key` header\nto a valid [LangSmith API key](https://docs.langchain.com/langsmith/create-account-api-key#create-an-api-key).\n\n'}},
#  {'info': {'version': '0.1.0'},
#   'paths': {'/api/v1/audit-logs': {'get': {'tags': ['audit-logs'],
#      'summary': 'Get Audit Logs'}}}},
# ...

# %%
for chunk in json_chunks[:]:
    print(chunk)
# Out:
# {'openapi': '3.1.0', 'info': {'title': 'LangSmith', 'description': 'The LangSmith API is used to programmatically create and manage LangSmith resources.\n\n## Host\nhttps://api.smith.langchain.com\n\n## Authentication\nTo authenticate with the LangSmith API, set the `X-Api-Key` header\nto a valid [LangSmith API key](https://docs.langchain.com/langsmith/create-account-api-key#create-an-api-key).\n\n'}}
# {'info': {'version': '0.1.0'}, 'paths': {'/api/v1/audit-logs': {'get': {'tags': ['audit-logs'], 'summary': 'Get Audit Logs'}}}}
# {'paths': {'/api/v1/audit-logs': {'get': {'description': "Retrieve audit log records for the authenticated user's organization in OCSF format.\n\nRequires both start_time and end_time parameters to filter logs within a date range.\nSupports cursor-based pagination.\n\nReturns results in OCSF API Activity (Class UID: 6003) format,\nwhich is compatible with security monitoring and SIEM tools.\nReference: https://schema.ocsf.io/1.7.0/classes/api_activity"}}}}
# ...

# %%
json=json_splitter.create_documents(text=json_file)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[164], line 1
# ----> 1 json=json_splitter.create_documents(text=json_file)
#
# TypeError: RecursiveJsonSplitter.create_documents() got an unexpected keyword argument 'text'

# %%
docs = json_splitter.create_documents(texts=[json_file])

for doc in docs[:3]:
    print(doc)
# Out:
# page_content='{"openapi": "3.1.0", "info": {"title": "LangSmith", "description": "The LangSmith API is used to programmatically create and manage LangSmith resources.\n\n## Host\nhttps://api.smith.langchain.com\n\n## Authentication\nTo authenticate with the LangSmith API, set the `X-Api-Key` header\nto a valid [LangSmith API key](https://docs.langchain.com/langsmith/create-account-api-key#create-an-api-key).\n\n"}}'
# page_content='{"info": {"version": "0.1.0"}, "paths": {"/api/v1/audit-logs": {"get": {"tags": ["audit-logs"], "summary": "Get Audit Logs"}}}}'
# ...

# %%
texts = json_splitter.split_text(json_file)
for text in texts[:]:
    print(text)
# Out:
# {"openapi": "3.1.0", "info": {"title": "LangSmith", "description": "The LangSmith API is used to programmatically create and manage LangSmith resources.\n\n## Host\nhttps://api.smith.langchain.com\n\n## Authentication\nTo authenticate with the LangSmith API, set the `X-Api-Key` header\nto a valid [LangSmith API key](https://docs.langchain.com/langsmith/create-account-api-key#create-an-api-key).\n\n"}}
# {"info": {"version": "0.1.0"}, "paths": {"/api/v1/audit-logs": {"get": {"tags": ["audit-logs"], "summary": "Get Audit Logs"}}}}
# {"paths": {"/api/v1/audit-logs": {"get": {"description": "Retrieve audit log records for the authenticated user's organization in OCSF format.\n\nRequires both start_time and end_time parameters to filter logs within a date range.\nSupports cursor-based pagination.\n\nReturns results in OCSF API Activity (Class UID: 6003) format,\nwhich is compatible with security monitoring and SIEM tools.\nReference: https://schema.ocsf.io/1.7.0/classes/api_activity"}}}}
# ...

# %%
print(text[0])
print(text[1])
# Out:
# {
# "

# %%
text
# Out:
# '{"definitions": {"types.FeedbackType": {"type": "string", "enum": ["continuous", "categorical", "freeform"], "x-enum-varnames": ["FeedbackTypeContinuous", "FeedbackTypeCategorical", "FeedbackTypeFreeform"]}}}'

# %%
texts
# Out:
# ['{"openapi": "3.1.0", "info": {"title": "LangSmith", "description": "The LangSmith API is used to programmatically create and manage LangSmith resources.\\n\\n## Host\\nhttps://api.smith.langchain.com\\n\\n## Authentication\\nTo authenticate with the LangSmith API, set the `X-Api-Key` header\\nto a valid [LangSmith API key](https://docs.langchain.com/langsmith/create-account-api-key#create-an-api-key).\\n\\n"}}',
#  '{"info": {"version": "0.1.0"}, "paths": {"/api/v1/audit-logs": {"get": {"tags": ["audit-logs"], "summary": "Get Audit Logs"}}}}',
# ...
